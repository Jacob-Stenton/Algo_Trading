# %% [markdown]
# # SMA Crossover Algorithmic Trading Strategy
#
# This is an area to learn some basics of algo trading and backtesting based on a simple smoothed moving average (SMA) crossover strategy.

# %% [markdown]
# ## Import Libraries
# ---

# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data
# ---

# %% [markdown]
# ### Downloading forex data

# %%
ticker = 'GBPUSD=X'
data = yf.download(ticker, period='1mo', interval='1h') # Previous month and the 1 hour time frame - yf.download --> pandas dataframe
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price                         Close      High       Low      Open   Volume
# Ticker                     GBPUSD=X  GBPUSD=X  GBPUSD=X  GBPUSD=X GBPUSD=X
# Datetime
# 2025-12-05 17:00:00+00:00  1.333138  1.333138  1.331966  1.332232        0
# 2025-12-05 18:00:00+00:00  1.333404  1.334063  1.333084  1.333084        0
# 2025-12-05 19:00:00+00:00  1.333440  1.333653  1.333031  1.333351        0
# 2025-12-05 20:00:00+00:00  1.333280  1.333387  1.332676  1.333244        0
# 2025-12-05 21:00:00+00:00  1.333156  1.333725  1.332871  1.333315        0
# ...                             ...       ...       ...       ...      ...
# 2026-01-05 13:00:00+00:00  1.345297  1.345569  1.342606  1.345569        0
# 2026-01-05 14:00:00+00:00  1.347328  1.347527  1.345261  1.345352        0
# 2026-01-05 15:00:00+00:00  1.350311  1.350402  1.347418  1.347564        0
# 2026-01-05 16:00:00+00:00  1.352466  1.352484  1.350421  1.350512        0
# 2026-01-05 17:00:00+00:00  1.353510  1.353821  1.352631  1.352649        0
#
# [471 rows x 5 columns]

# %% [markdown]
# ### Plot of forex data

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(data['Close'])
plt.show()

# %% [markdown]
# ## Creating Smoothed Moving Averages
#
# ---

# %% [markdown]
# ### Adding moving averages to current data

# %%
# Fast and Slow SMA
fast = 10
slow = 27

# %% [markdown]
# These are our lookback windows for the SMAs. Fast must be a smaller number than slow so it stays more reactive to recent price movements. These numbers are subject to some experimentation for the 'best' outcome.

# %%
data['FastSMA'] = data['Close'].rolling(window=fast).mean()
data['SlowSMA'] = data['Close'].rolling(window=slow).mean()

# %%
# Get rid of NaNs

plot_data = data.dropna()
plot_data
# Out:
# Price                         Close      High       Low      Open   Volume  \
# Ticker                     GBPUSD=X  GBPUSD=X  GBPUSD=X  GBPUSD=X GBPUSD=X
# Datetime
# 2025-12-08 20:00:00+00:00  1.332605  1.332978  1.332392  1.332729        0
# 2025-12-08 21:00:00+00:00  1.332214  1.332942  1.331735  1.332552        0
# 2025-12-08 22:00:00+00:00  1.332037  1.333262  1.331930  1.332161        0
# 2025-12-08 23:00:00+00:00  1.332676  1.332676  1.332054  1.332054        0
# 2025-12-09 00:00:00+00:00  1.332214  1.332907  1.332072  1.332782        0
# ...                             ...       ...       ...       ...      ...
# 2026-01-05 13:00:00+00:00  1.345297  1.345569  1.342606  1.345569        0
# 2026-01-05 14:00:00+00:00  1.347328  1.347527  1.345261  1.345352        0
# 2026-01-05 15:00:00+00:00  1.350311  1.350402  1.347418  1.347564        0
# 2026-01-05 16:00:00+00:00  1.352466  1.352484  1.350421  1.350512        0
# 2026-01-05 17:00:00+00:00  1.353510  1.353821  1.352631  1.352649        0
#
# Price                       FastSMA   SlowSMA
# Ticker
# Datetime
# 2025-12-08 20:00:00+00:00  1.332234  1.332857
# 2025-12-08 21:00:00+00:00  1.332239  1.332823
# 2025-12-08 22:00:00+00:00  1.332241  1.332772
# 2025-12-08 23:00:00+00:00  1.332310  1.332744
# 2025-12-09 00:00:00+00:00  1.332268  1.332705
# ...                             ...       ...
# 2026-01-05 13:00:00+00:00  1.344171  1.344965
# 2026-01-05 14:00:00+00:00  1.344639  1.345045
# 2026-01-05 15:00:00+00:00  1.345377  1.345274
# 2026-01-05 16:00:00+00:00  1.346260  1.345565
# 2026-01-05 17:00:00+00:00  1.347376  1.345848
#
# [445 rows x 7 columns]

# %% [markdown]
# ### Plotting Moving Averages

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(data['Close'], color='blue', label='Close')
ax.plot(data['FastSMA'], color='orange', label='Fast')
ax.plot(data['SlowSMA'], color='green', label='Slow')
ax.legend()
plt.show()

# %% [markdown]
# Looking at the plot we can see the fast SMA line (orange) frequently crosses above and below our slow line. The idea behind this strategy is to buy when the fast line crosses about the slow line and sell when the inverse happens.

# %% [markdown]
# ## Strategy
# ---

# %% [markdown]
# ### Logging crossovers

# %%
data['Strategy'] = np.where(data['FastSMA'] > data['SlowSMA'], 1, -1)
data['Strategy'] = data['Strategy'].shift(1)

# %%
data
# Out:
# Price                         Close      High       Low      Open   Volume  \
# Ticker                     GBPUSD=X  GBPUSD=X  GBPUSD=X  GBPUSD=X GBPUSD=X
# Datetime
# 2025-12-05 17:00:00+00:00  1.333138  1.333138  1.331966  1.332232        0
# 2025-12-05 18:00:00+00:00  1.333404  1.334063  1.333084  1.333084        0
# 2025-12-05 19:00:00+00:00  1.333440  1.333653  1.333031  1.333351        0
# 2025-12-05 20:00:00+00:00  1.333280  1.333387  1.332676  1.333244        0
# 2025-12-05 21:00:00+00:00  1.333156  1.333725  1.332871  1.333315        0
# ...                             ...       ...       ...       ...      ...
# 2026-01-05 13:00:00+00:00  1.345297  1.345569  1.342606  1.345569        0
# 2026-01-05 14:00:00+00:00  1.347328  1.347527  1.345261  1.345352        0
# 2026-01-05 15:00:00+00:00  1.350311  1.350402  1.347418  1.347564        0
# 2026-01-05 16:00:00+00:00  1.352466  1.352484  1.350421  1.350512        0
# 2026-01-05 17:00:00+00:00  1.353510  1.353821  1.352631  1.352649        0
#
# Price                       FastSMA   SlowSMA Strategy
# Ticker
# Datetime
# 2025-12-05 17:00:00+00:00       NaN       NaN      NaN
# 2025-12-05 18:00:00+00:00       NaN       NaN     -1.0
# 2025-12-05 19:00:00+00:00       NaN       NaN     -1.0
# 2025-12-05 20:00:00+00:00       NaN       NaN     -1.0
# 2025-12-05 21:00:00+00:00       NaN       NaN     -1.0
# ...                             ...       ...      ...
# 2026-01-05 13:00:00+00:00  1.344171  1.344965     -1.0
# 2026-01-05 14:00:00+00:00  1.344639  1.345045     -1.0
# 2026-01-05 15:00:00+00:00  1.345377  1.345274     -1.0
# 2026-01-05 16:00:00+00:00  1.346260  1.345565      1.0
# 2026-01-05 17:00:00+00:00  1.347376  1.345848      1.0
#
# [471 rows x 8 columns]
