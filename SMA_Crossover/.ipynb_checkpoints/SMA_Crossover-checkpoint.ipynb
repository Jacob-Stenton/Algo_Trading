# %% [markdown]
# # SMA Crossover Algorithmic Trading Strategy
#
# This is an area to learn some basics of algo trading and backtesting based on a simple smoothed moving average (SMA) crossover strategy.

# %% [markdown]
# ## Import Libraries
# ---

# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data
# ---

# %% [markdown]
# ### Downloading forex data

# %%
ticker = 'GBPUSD=X'
yf_data = yf.download(ticker, period='max', interval='1d') # Previous month and the 1 hour time frame - yf.download --> pandas dataframe

lookback = 2000 # looking back at the last n ticks. e.g. 10,000 minutes/hours/days
data = yf_data[-lookback:].copy()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.columns = data.columns.droplevel(1)
# Required to remove the extra 'GPDUSD=X' header for easier handling later on.

data
# Out:
# Price          Close      High       Low      Open  Volume
# Date
# 2018-05-01  1.377221  1.377600  1.359102  1.377221       0
# 2018-05-02  1.360933  1.366475  1.358253  1.361063       0
# 2018-05-03  1.357386  1.362899  1.354023  1.357368       0
# 2018-05-04  1.357239  1.358696  1.349455  1.357239       0
# 2018-05-07  1.353198  1.357589  1.351717  1.353327       0
# ...              ...       ...       ...       ...     ...
# 2025-12-30  1.351099  1.353015  1.345171  1.350986       0
# 2025-12-31  1.346720  1.347654  1.340339  1.346783       0
# 2026-01-02  1.347364  1.350165  1.343526  1.347491       0
# 2026-01-05  1.343797  1.352558  1.341544  1.343941       0
# 2026-01-06  1.351041  1.356779  1.349528  1.354261       0
#
# [2000 rows x 5 columns]

# %% [markdown]
# ### Plot of forex data

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(data['Close'])
plt.show()

# %% [markdown]
# ## Creating Smoothed Moving Averages
#
# ---

# %% [markdown]
# ### Adding moving averages to current data

# %%
# Fast and Slow SMA
fast = 10
slow = 27

# %% [markdown]
# These are our lookback windows for the SMAs. Fast must be a smaller number than slow so it stays more reactive to recent price movements. These numbers are subject to some experimentation for the 'best' outcome.

# %%
data['FastSMA'] = data['Close'].rolling(window=fast).mean()
data['SlowSMA'] = data['Close'].rolling(window=slow).mean()

# %%
# Get rid of NaNs

plot_data = data.dropna()
plot_data
# Out:
# Price          Close      High       Low      Open  Volume   FastSMA   SlowSMA
# Date
# 2018-06-06  1.340608  1.344447  1.339998  1.340698       0  1.332852  1.346544
# 2018-06-07  1.342156  1.347346  1.337506  1.342462       0  1.333354  1.345245
# 2018-06-08  1.341922  1.343634  1.335773  1.341562       0  1.333712  1.344541
# 2018-06-11  1.341382  1.344050  1.334579  1.341112       0  1.334760  1.343948
# 2018-06-12  1.337435  1.342282  1.334739  1.337149       0  1.335347  1.343215
# ...              ...       ...       ...       ...     ...       ...       ...
# 2025-12-30  1.351099  1.353015  1.345171  1.350986       0  1.344434  1.332653
# 2025-12-31  1.346720  1.347654  1.340339  1.346783       0  1.345299  1.334069
# 2026-01-02  1.347364  1.350165  1.343526  1.347491       0  1.345786  1.335466
# 2026-01-05  1.343797  1.352558  1.341544  1.343941       0  1.346420  1.336695
# 2026-01-06  1.351041  1.356779  1.349528  1.354261       0  1.347670  1.337998
#
# [1974 rows x 7 columns]

# %% [markdown]
# ### Plotting Moving Averages

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(data['Close'], color='blue', label='Close')
ax.plot(data['FastSMA'], color='orange', label='Fast')
ax.plot(data['SlowSMA'], color='green', label='Slow')
ax.legend()
plt.show()

# %% [markdown]
# Looking at the plot we can see the fast SMA line (orange) frequently crosses above and below our slow line. The idea behind this strategy is to buy when the fast line crosses about the slow line and sell when the inverse happens.

# %% [markdown]
# ## Strategy
# ---

# %% [markdown]
# ### Finding crossovers

# %%
data['Strategy'] = np.where(data['FastSMA'] > data['SlowSMA'], 1, -1)
# crossovers will show as 1 (fast above slow) and -1 (slow above fast) - 1 = long -1 = short

data['Strategy'] = data['Strategy'].shift(1)
# strategy data must be shifted over once as we don't know the closing prices (and therefore SMAs) until they've closed.

# %% [markdown]
# ### Does it work?

# %%
data['Strategy_Returns'] = (1 + data['Close'].pct_change() * data['Strategy']).cumprod() - 1
data['Asset_Returns'] = (1 + data['Close'].pct_change()).cumprod() -1

data
# Out:
# Price          Close      High       Low      Open  Volume   FastSMA  \
# Date
# 2018-05-01  1.377221  1.377600  1.359102  1.377221       0       NaN
# 2018-05-02  1.360933  1.366475  1.358253  1.361063       0       NaN
# 2018-05-03  1.357386  1.362899  1.354023  1.357368       0       NaN
# 2018-05-04  1.357239  1.358696  1.349455  1.357239       0       NaN
# 2018-05-07  1.353198  1.357589  1.351717  1.353327       0       NaN
# ...              ...       ...       ...       ...     ...       ...
# 2025-12-30  1.351099  1.353015  1.345171  1.350986       0  1.344434
# 2025-12-31  1.346720  1.347654  1.340339  1.346783       0  1.345299
# 2026-01-02  1.347364  1.350165  1.343526  1.347491       0  1.345786
# 2026-01-05  1.343797  1.352558  1.341544  1.343941       0  1.346420
# 2026-01-06  1.351041  1.356779  1.349528  1.354261       0  1.347670
#
# Price        SlowSMA  Strategy  Strategy_Returns  Asset_Returns
# Date
# 2018-05-01       NaN       NaN               NaN            NaN
# 2018-05-02       NaN      -1.0          0.011827      -0.011827
# 2018-05-03       NaN      -1.0          0.014463      -0.014402
# 2018-05-04       NaN      -1.0          0.014574      -0.014509
# 2018-05-07       NaN      -1.0          0.017594      -0.017443
# ...              ...       ...               ...            ...
# 2025-12-30  1.332653       1.0          0.086967      -0.018967
# 2025-12-31  1.334069       1.0          0.083443      -0.022147
# 2026-01-02  1.335466       1.0          0.083961      -0.021679
# 2026-01-05  1.336695       1.0          0.081092      -0.024269
# 2026-01-06  1.337998       1.0          0.086920      -0.019009
#
# [2000 rows x 10 columns]

# %%
plot_data = data.dropna()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(data['Strategy_Returns'], color='Red', label='Strategy Returns')
ax.plot(data['Asset_Returns'], color='Green', label='Asset Returns')
ax.legend()
plt.show()

# %% [markdown]
# What we see is that with a fast of 10 and a slow of 27 there is an area where it is outperforming but overall the strategy does not work. The goal is for consistant growth, where here it is relativley flat. However, there is definetley room to experiment with different time frames and lookback windows for our SMAs.

# %%
def create_strat_data(yf_data, fast, slow):
    data = yf_data
    data.columns = data.columns.droplevel(1)
    
    data['FastSMA'] = data['Close'].rolling(window=fast).mean()
    data['SlowSMA'] = data['Close'].rolling(window=slow).mean()
    
    data['Strategy'] = np.where(data['FastSMA'] > data['SlowSMA'], 1, -1)
    data['Strategy'] = data['Strategy'].shift(1)
    
    data['Strategy_Returns'] = (1 + data['Close'].pct_change() * data['Strategy']).cumprod() - 1
    data['Asset_Returns'] = (1 + data['Close'].pct_change()).cumprod() - 1

    return data

# %%
GDPUSD_data = create_strat_data(yf.download('GBPUSD=X', period='max', interval='1d'), fast, slow)

fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(GDPUSD_data['Strategy_Returns'], color='Red', label='Strategy Returns')
ax.plot(GDPUSD_data['Asset_Returns'], color='Green', label='Asset Returns')
ax.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# If we backtest as far back as we can go we see that the strategy isn't very good at all.
#
# We can also test with another ticker. This time we'll try Tesla stock.

# %%
yf_tsla_data = yf.download('TSLA', period='max', interval='1d') # Previous month and the 1 hour time frame - yf.download --> pandas dataframe
TSLA_data = create_strat_data(yf_tsla_data, fast, slow)

fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(TSLA_data['Strategy_Returns'], color='Red', label='Strategy Returns')
ax.plot(TSLA_data['Asset_Returns'], color='Green', label='Asset Returns')
ax.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
yf_spy_data = yf.download('SPY', period='max', interval='1d') # Previous month and the 1 hour time frame - yf.download --> pandas dataframe
SPY_data = create_strat_data(yf_spy_data, fast, slow)

fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(SPY_data['Strategy_Returns'], color='Red', label='Strategy Returns')
ax.plot(SPY_data['Asset_Returns'], color='Green', label='Asset Returns')
ax.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# One thing that is very important to note is that shorting creates quite a lot of drawback, this is potentially bevause SMAs are a lagging indicator. Shorter lookbacks might improve this. Here is TSLA with long only.

# %%
def create_strat_data_long(yf_data, fast, slow):
    data = yf_data
    data.columns = data.columns.droplevel(1)
    
    data['FastSMA'] = data['Close'].rolling(window=fast).mean()
    data['SlowSMA'] = data['Close'].rolling(window=slow).mean()
    
    data['Strategy'] = np.where(data['FastSMA'] > data['SlowSMA'], 1, 0)
    data['Strategy'] = data['Strategy'].shift(1)
    
    data['Strategy_Returns'] = (1 + data['Close'].pct_change() * data['Strategy']).cumprod() - 1
    data['Asset_Returns'] = (1 + data['Close'].pct_change()).cumprod() - 1

    return data

yf_tsla_data = yf.download('TSLA', period='max', interval='1d') # Previous month and the 1 hour time frame - yf.download --> pandas dataframe
TSLA_data = create_strat_data_long(yf_tsla_data, fast, slow)

fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(TSLA_data['Strategy_Returns'], color='Red', label='Strategy Returns')
ax.plot(TSLA_data['Asset_Returns'], color='Green', label='Asset Returns')
ax.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Better, but still no better than simply buying and holding. There are also considerable periods where no progress is being made.
