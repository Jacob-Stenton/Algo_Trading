# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# %%
fast = 10
mid = 20
slow = 30

# %%
def create_strat_data(yf_data, fast, mid, slow):
    data = yf_data.copy()
    data.columns = data.columns.droplevel(1)
    
    data['FastSMA'] = data['Close'].rolling(window=fast).mean()
    data['MidSMA'] = data['Close'].rolling(window=mid).mean()
    data['SlowSMA'] = data['Close'].rolling(window=slow).mean()

    data['Strategy'] = 0 

    long  = (data['FastSMA'] > data['MidSMA']) & (data['MidSMA'] > data['SlowSMA'])
    short = (data['FastSMA'] < data['MidSMA']) & (data['MidSMA'] < data['SlowSMA'])
    
    data.loc[long,  'Strategy'] = 1
    data.loc[short, 'Strategy'] = -1
    
    s = data['Strategy'] # Forward filling on long positions
    data['Strategy'] = (
        s.where(s != 0)
         .mask(s == -1, -1)
         .ffill()
         .fillna(0)
         .shift(1)
    )   
    
    data['Strategy_Returns'] = (1 + data['Close'].pct_change() * data['Strategy']).cumprod() - 1
    data['Asset_Returns'] = (1 + data['Close'].pct_change()).cumprod() - 1

    return data

# %%
yf_ticker_data = yf.download('GBPUSD=X', period='10y', interval='1d') 
data = create_strat_data(yf_ticker_data, fast, mid, slow)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plot_data = data.dropna()
plot_data
# Out:
# Price          Close      High       Low      Open  Volume   FastSMA  \
# Date
# 2016-02-19  1.433322  1.434103  1.425314  1.433096       0  1.443188
# 2016-02-22  1.426595  1.430104  1.406668  1.427002       0  1.440726
# 2016-02-23  1.414807  1.415709  1.406608  1.415108       0  1.437846
# 2016-02-24  1.401345  1.401738  1.388118  1.400953       0  1.433321
# 2016-02-25  1.392952  1.399776  1.390434  1.393107       0  1.427352
# ...              ...       ...       ...       ...     ...       ...
# 2026-01-05  1.343797  1.352558  1.341544  1.343941       0  1.346420
# 2026-01-06  1.353400  1.356815  1.349291  1.353455       0  1.347906
# 2026-01-07  1.350056  1.351753  1.347019  1.350038       0  1.349141
# 2026-01-08  1.345931  1.346638  1.341760  1.345949       0  1.349035
# 2026-01-09  1.339639  1.345116  1.339567  1.343526       0  1.347863
#
# Price         MidSMA   SlowSMA  Strategy  Strategy_Returns  Asset_Returns
# Date
# 2016-02-19  1.440130  1.438337       0.0          0.000000      -0.013201
# 2016-02-22  1.440160  1.437474       1.0         -0.004693      -0.017832
# 2016-02-23  1.439685  1.436154       1.0         -0.012917      -0.025948
# 2016-02-24  1.438037  1.434745       1.0         -0.022309      -0.035216
# 2016-02-25  1.436439  1.433150       1.0         -0.028165      -0.040994
# ...              ...       ...       ...               ...            ...
# 2026-01-05  1.341227  1.333984       1.0          0.092851      -0.074836
# 2026-01-06  1.342288  1.335481       1.0          0.100661      -0.068225
# 2026-01-07  1.343168  1.336828       1.0          0.097941      -0.070527
# 2026-01-08  1.343830  1.338005       1.0          0.094587      -0.073367
# 2026-01-09  1.344295  1.338797       1.0          0.089469      -0.077699
#
# [2573 rows x 11 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(data['Close'], color='blue', label='Close')
ax.plot(data['FastSMA'], color='orange', label='Fast')
ax.plot(data['MidSMA'], color='purple', label='Mid')
ax.plot(data['SlowSMA'], color='green', label='Slow')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(data['Strategy_Returns'], color='Red', label='Strategy Returns')
ax.plot(data['Asset_Returns'], color='Green', label='Asset Returns')
ax.legend()
plt.show()
